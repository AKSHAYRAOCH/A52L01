# %% [markdown]
# <a href="https://colab.research.google.com/github/AKSHAYRAOCH/A52L01/blob/main/J_component_batch_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Life_Expectancy_Data.csv')
print(d)
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %%
d=d.fillna(0)

# %% [markdown]
# # New Section

# %%
a1=d['Adult Mortality']
y=d['Life expectancy ']
print(a1,y)
# Out:
# 0       263.0
# 1       271.0
# 2       268.0
# 3       272.0
# 4       275.0
#         ...
# 2933    723.0
# 2934    715.0
# 2935     73.0
# 2936    686.0
# 2937    665.0
# Name: Adult Mortality, Length: 2938, dtype: float64 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
from matplotlib import pyplot as pt
a1=d['Adult Mortality']
y=d['Life expectancy ']
pt.plot(a1,y)

# %%
from matplotlib import pyplot as pt
a2=d['infant deaths']
y=d['Life expectancy ']
pt.plot(a2,y)

# %%
from matplotlib import pyplot as pt
a3=d['Alcohol']
y=d['Life expectancy ']
pt.plot(a3,y)

# %%
from matplotlib import pyplot as pt
a4=d['percentage expenditure']
y=d['Life expectancy ']
pt.plot(a4,y)

# %%
from matplotlib import pyplot as pt
a5=d['Hepatitis B']
y=d['Life expectancy ']
pt.plot(a5,y)

# %%
from matplotlib import pyplot as pt
a6=d['Measles ']
y=d['Life expectancy ']
pt.plot(a6,y)

# %%
from matplotlib import pyplot as pt
a7=d[' BMI ']
y=d['Life expectancy ']
pt.plot(a7,y)

# %%
from matplotlib import pyplot as pt
a8=d['under-five deaths ']
y=d['Life expectancy ']
pt.plot(a8,y)

# %%
from matplotlib import pyplot as pt
a9=d['Polio']
y=d['Life expectancy ']
pt.plot(a9,y)

# %%
from matplotlib import pyplot as pt
a10=d['Total expenditure']
y=d['Life expectancy ']
pt.plot(a10,y)

# %%
from matplotlib import pyplot as pt
a11=d['Diphtheria ']
y=d['Life expectancy ']
pt.plot(a11,y)

# %%
from matplotlib import pyplot as pt
a12=d[' HIV/AIDS']
y=d['Life expectancy ']
pt.plot(a12,y)

# %%
from matplotlib import pyplot as pt
a13=d['GDP']
y=d['Life expectancy ']
pt.plot(a13,y)

# %%
from matplotlib import pyplot as pt
a14=d['Population']
y=d['Life expectancy ']
pt.plot(a14,y)

# %%
from matplotlib import pyplot as pt
a15=d[' thinness  1-19 years']
y=d['Life expectancy ']
pt.plot(a15,y)

# %%
from matplotlib import pyplot as pt
a16=d[' thinness 5-9 years']
y=d['Life expectancy ']
pt.plot(a16,y)

# %%
from matplotlib import pyplot as pt
a17=d['Income composition of resources']
y=d['Life expectancy ']
pt.plot(a17,y)

# %%
from matplotlib import pyplot as pt
a18=d['Schooling']
y=d['Life expectancy ']
pt.plot(a18,y)

# %%
ymean=[]
def linear(b0,b1,b2,b3,b4,b5,b6,b7,b8,b9):
  sum=0;
  ybar=[]
  ypp=[]
  for i in range(0,len(a1)):
    ybar.append(b0+b1*int(a1[i])+b2*int(a2[i])+b3*int(a3[i])+b4*int(a4[i])+b5*int(a5[i])+b6*int(a6[i])+b7*int(a7[i])+b8*int(a8[i])+b9*int(a9[i]))
  for i in range(0,len(a1)):
    ypp.append((int(y[i])-ybar[i])**2)
  for i in range(0,len(a1)):
    sum=sum+ypp[i]
  ymean.append(sum/len(a1))
for i in range(0,50):
  linear(i,i,i,i,i,i,i,i,i,i+10)

# %%
print(ymean)
# Out:
# [621714.9016337645, 154071043.64567733, 604756176.2426821, 1352677112.6926482, 2397833852.9955754, 3740226397.1514635, 5379854745.160314, 7316718897.022124, 9550818852.736897, 12082154612.304628, 14910726175.725323, 18036533542.998978, 21459576714.125595, 25179855689.105175, 29197370467.937714, 33512121050.623215, 38124107437.161674, 43033329627.5531, 48239787621.79748, 53743481419.89483, 59544411021.84513, 65642576427.6484, 72037977637.30463, 78730614650.81381, 85720487468.17596, 93007596089.39108, 100591940514.45915, 108473520743.38019, 116652336776.15419, 125128388612.78114, 133901676253.26106, 142972199697.59393, 152339958945.7798, 162004953997.81857, 171967184853.71036, 182226651513.45508, 192783353977.05276, 203637292244.50342, 214788466315.807, 226236876190.9636, 237982521869.9731, 250025403352.8356, 262365520639.55106, 275002873730.11945, 287937462624.54083, 301169287322.8152, 314698347824.9425, 328524644130.9227, 342648176240.756, 357068944154.44214]

# %%
if(ymean[0]<ymean[1]):
  result=ymean[0]
else:
  result=ymean[1]
for i in range(0,len(ymean)):
  if(result>ymean[i]):
    result=ymean[i]
    
print("the less mean square error is",result)
# Out:
# the less mean square error is 621714.9016337645
